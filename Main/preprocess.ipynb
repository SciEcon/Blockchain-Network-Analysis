# %%
import pandas as pd
import numpy as np

# %%
dtypes = {'token_address':str, 'from_address':str, 'to_address':str, 'timestamp':str, 'value':np.float64}
AAVE = pd.read_csv('../Data/AAVE_22-07-25.csv', dtype=dtypes)
AAVE = AAVE[AAVE['timestamp'] <= '2022-07-12 23:59:59+00:00']
AAVE.to_csv('../Data/AAVE_22-07-12.csv', index=False)

# %%
dtypes = {'token_address':str, 'from_address':str, 'to_address':str, 'timestamp':str, 'value':np.float64}
COMP = pd.read_csv('../Data/COMP_22-07-25.csv', dtype=dtypes)
COMP = COMP[COMP['timestamp'] <= '2022-07-12 23:59:59+00:00']
COMP.to_csv('../Data/COMP_22-07-12.csv', index=False)

# %%
dtypes = {'token_address':str, 'from_address':str, 'to_address':str, 'timestamp':str, 'value':np.float64}
Dai20 = pd.read_csv('../Data/Dai_2020-12-31.csv', dtype=dtypes)

# %%
Dai20
# Out:
#                                       token_address  \
# 0        0x6b175474e89094c44da98b954eedeac495271d0f
# 1        0x6b175474e89094c44da98b954eedeac495271d0f
# 2        0x6b175474e89094c44da98b954eedeac495271d0f
# 3        0x6b175474e89094c44da98b954eedeac495271d0f
# 4        0x6b175474e89094c44da98b954eedeac495271d0f
# ...                                             ...
# 6412134  0x6b175474e89094c44da98b954eedeac495271d0f
# 6412135  0x6b175474e89094c44da98b954eedeac495271d0f
# 6412136  0x6b175474e89094c44da98b954eedeac495271d0f
# 6412137  0x6b175474e89094c44da98b954eedeac495271d0f
# 6412138  0x6b175474e89094c44da98b954eedeac495271d0f
#
#                                        from_address  \
# 0        0xa478c2975ab1ea89e8196811f51a7b7ade33eb11
# 1        0x564286362092d8e7936f0549571a803b203aaced
# 2        0x3d687333c7259bb0ca5319462f5c11826987b883
# 3        0xa863cc2a7a859b2b76128340d07d025a19f0fc9f
# 4        0x896dc58182c3b78598c11aa10f940257a1ce32b1
# ...

# %%
dtypes = {'token_address':str, 'from_address':str, 'to_address':str, 'timestamp':str, 'value':np.float64}
Dai21 = pd.read_csv('../Data/Dai_2021-12-31.csv', dtype=dtypes)
Dai22 = pd.read_csv('../Data/Dai_2022-12-31.csv', dtype=dtypes)

# %%
Dai22 = Dai22[Dai22['timestamp'] <= '2022-07-12 23:59:59+00:00']

# %%
Dai22
# Out:
#                                       token_address  \
# 115537   0x6b175474e89094c44da98b954eedeac495271d0f
# 115538   0x6b175474e89094c44da98b954eedeac495271d0f
# 115539   0x6b175474e89094c44da98b954eedeac495271d0f
# 115540   0x6b175474e89094c44da98b954eedeac495271d0f
# 115541   0x6b175474e89094c44da98b954eedeac495271d0f
# ...                                             ...
# 1969056  0x6b175474e89094c44da98b954eedeac495271d0f
# 1969057  0x6b175474e89094c44da98b954eedeac495271d0f
# 1969058  0x6b175474e89094c44da98b954eedeac495271d0f
# 1969059  0x6b175474e89094c44da98b954eedeac495271d0f
# 1969060  0x6b175474e89094c44da98b954eedeac495271d0f
#
#                                        from_address  \
# 115537   0xbeefbabeea323f07c59926295205d3b7a17e8638
# 115538   0x0eae044f00b0af300500f090ea00027097d03000
# 115539   0x055475920a8c93cffb64d039a8205f7acc7722d3
# 115540   0xbeefbabeea323f07c59926295205d3b7a17e8638
# 115541   0x0000000000007f150bd6f54c40a34d7c3d5e9f56
# ...

# %%
Dai = pd.concat([Dai22, Dai21, Dai20])

# %%
Dai
# Out:
#                                       token_address  \
# 115537   0x6b175474e89094c44da98b954eedeac495271d0f
# 115538   0x6b175474e89094c44da98b954eedeac495271d0f
# 115539   0x6b175474e89094c44da98b954eedeac495271d0f
# 115540   0x6b175474e89094c44da98b954eedeac495271d0f
# 115541   0x6b175474e89094c44da98b954eedeac495271d0f
# ...                                             ...
# 6412134  0x6b175474e89094c44da98b954eedeac495271d0f
# 6412135  0x6b175474e89094c44da98b954eedeac495271d0f
# 6412136  0x6b175474e89094c44da98b954eedeac495271d0f
# 6412137  0x6b175474e89094c44da98b954eedeac495271d0f
# 6412138  0x6b175474e89094c44da98b954eedeac495271d0f
#
#                                        from_address  \
# 115537   0xbeefbabeea323f07c59926295205d3b7a17e8638
# 115538   0x0eae044f00b0af300500f090ea00027097d03000
# 115539   0x055475920a8c93cffb64d039a8205f7acc7722d3
# 115540   0xbeefbabeea323f07c59926295205d3b7a17e8638
# 115541   0x0000000000007f150bd6f54c40a34d7c3d5e9f56
# ...

# %%
Dai.to_csv('../Data/Dai_22-07-12.csv', index=False)
